# %% [markdown]
# Judul penelitian   : "Prediksi Tingkat Stress Seseorang Dengan Menggunakan Metode Classification Decision Tree"
# - NIM               : 201351016
# - Nama              : Andika Muhammad Aditya
# - Kelas             : IF PAGI B
# - Mata Kuliah       : Data Mining
# - Dosen Pengampu    : Teguh Iman Hermanto, M.Kom.
#
# # ======================================

# %% [markdown]
# # Import Library

# %% [markdown]
# Meng-importkan kumpulan dari fungsi-fungsi (library) python yang akan dipakai dalam perhitungan, agar mempercepat pengembangan aplikasi atau memungkinkan dalam menambahkan fitur yang kompleks dengan lebih mudah.
# Berikut kumpulan dari fungsi-fungsi (library) python yang dipakai dalam pembuatan aplikasi "Prediksi Tingkat Stress Seseorang Dengan Menggunakan Metode Classification Decision Tree".
#
# -  Pandas: Library untuk memanipulasi data,
# -  Numpy: Library untuk melakukan operasi matriks,
# -  Matplotlib: Library untuk melakukan visualisasi data,

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Memuat dan Membaca Dataset
# Membaca dataset yang digunakan dan menampilkan random sample dataset dan 100 data teratas

# %%
df = pd.read_csv('Stress-Lysis.csv')
df.sample()
# Out:
#       Humidity  Temperature  Step_count  Stress_Level
# 1496     18.35        87.35          16             1

# %% [markdown]
# ### Deskripsi Dataset

# %%
df.head(100) #Menampilkan 100 data teratas
# Out:
#     Humidity  Temperature  Step_count  Stress_Level
# 0      21.33        90.33         123             1
# 1      21.41        90.41          93             1
# 2      27.12        96.12         196             2
# 3      27.64        96.64         177             2
# 4      10.87        79.87          87             0
# ..       ...          ...         ...           ...
# 95     11.89        80.89           7             0
# 96     25.89        94.89         144             2
# 97     29.50        98.50         150             2
# 98     21.38        90.38         128             1
# 99     14.18        83.18          54             0
#
# [100 rows x 4 columns]

# %% [markdown]
# # BUSINESS UNDERSTANDING
# - Masalah : Tingkat stres yang tinggi dapat memiliki dampak negatif terhadap kesejahteraan individu. Penelitian ini bertujuan untuk memprediksi tingkat stress seseorang menggunakan metode Classification Decision Tree. Dengan menggunakan metode ini, diharapkan dapat ditemukan pola-pola dalam data yang memungkinkan untuk mengidentifikasi individu dengan tingkat stres yang tinggi. Hal ini akan memungkinkan untuk memberikan intervensi yang tepat dan mencegah masalah kesehatan mental yang lebih serius.
#
# - Tujuan : Tujuan penelitian ini adalah untuk membangun model prediksi yang dapat mengklasifikasikan tingkat stress seseorang berdasarkan data yang ada. Model ini dapat membantu dalam mengidentifikasi individu yang rentan terhadap tingkat stress yang tinggi, sehingga dapat dilakukan langkah-langkah pencegahan atau intervensi yang tepat.
#
# - Manfaat Penelitian: Penelitian ini memiliki manfaat yang potensial dalam berbagai konteks, seperti:
#     - Kesehatan Mental: Dapat membantu dalam mengidentifikasi individu dengan tingkat stress yang tinggi sehingga dapat dilakukan intervensi dini dan penanganan yang tepat untuk mencegah masalah kesehatan mental yang lebih serius.
#     - Pengelolaan Stres: Dapat memberikan pemahaman yang lebih baik tentang faktor-faktor yang mempengaruhi tingkat stress seseorang, sehingga dapat membantu individu untuk mengelola stres dengan lebih efektif.
#     - Sumber Daya Manusia: Dalam konteks organisasi, penelitian ini dapat digunakan untuk mengidentifikasi tingkat stress karyawan sehingga perusahaan dapat mengambil tindakan yang tepat untuk meningkatkan kesejahteraan dan produktivitas karyawan.

# %% [markdown]
# - Metode yang Digunakan: Penelitian ini menggunakan metode Classification Decision Tree untuk membangun model prediksi. Decision Tree adalah salah satu metode klasifikasi yang populer dalam machine learning. Dalam konteks ini, Decision Tree akan digunakan untuk mempelajari pola-pola dari data yang ada dan membangun suatu pohon keputusan yang dapat digunakan untuk mengklasifikasikan tingkat stress seseorang.
#
# - Harapan dari penelitian ini adalah dapat mengembangkan model prediksi tingkat stres seseorang dengan menggunakan metode Classification Decision Tree yang akurat dan dapat diandalkan. Dengan memiliki model prediksi yang handal, diharapkan dapat memberikan informasi yang berharga dalam mengidentifikasi individu dengan tingkat stres yang tinggi, sehingga dapat dilakukan intervensi dan penanganan yang tepat secara dini. Selain itu, diharapkan juga dapat memberikan pemahaman yang lebih baik tentang faktor-faktor yang mempengaruhi tingkat stres sehingga dapat membantu dalam upaya pencegahan dan pengelolaan stres yang lebih efektif. Hasil penelitian ini diharapkan dapat memberikan kontribusi dalam bidang kesehatan mental dan meningkatkan kualitas hidup individu dengan mengurangi tingkat stres yang berlebihan.

# %% [markdown]
# # DATA UNDERSTANDING
# - Menggunakan dataset Stress-Lysis.csv, sumber data (LAAVANYA RACHAKONDA) : https://www.kaggle.com/datasets/laavanya/stress-level-detection?select=Stress-Lysis.csv
#
# - Dataset yang digunakan berisi informasi mengenai :
#     - Humidity (Kelembapan (%RH)): Kolom ini mewakili tingkat kelembaban yang tercatat selama pengumpulan data. Kelembaban mengacu pada jumlah kelembaban atau uap air yang ada di udara pada ruangan yang sering ditempati oleh seseorang. Biasanya diukur sebagai Persentase kelembapan relatif (%RH) dan dapat mempengaruhi kenyamanan dan kesejahteraan individu.
#     - Temperature (Suhu (F/Fahrenheit)): Kolom ini berisi pembacaan suhu yang tercatat selama pengumpulan data. Suhu mengacu pada tingkat panas atau dingin di lingkungan dan biasanya ditempati oleh pasien diukur dalam derajat Fahrenheit (F). Suhu dapat mempengaruhi kondisi fisiologis dan psikologis, termasuk tingkat stres.
#     - Step_count (Jumlah Langkah per hari): Kolom ini mengindikasikan jumlah langkah atau aktivitas fisik yang tercatat. Jumlah langkah adalah ukuran pergerakan fisik atau olahraga. Ini dapat mencerminkan tingkat aktivitas fisik atau perilaku sedentari dan sering dikaitkan dengan kesehatan dan kesejahteraan secara keseluruhan.
#     - Stress_Level (Tingkat Stress yang dikelompokkan menjadi 3 kategori yaitu 0 = Stres rendah, 1 = Stres Sedang, 2 = Stres Tinggi):  Kolom ini mewakili tingkat stres yang tercatat selama pengumpulan data. Tingkat stres dapat bersifat subjektif atau diukur melalui berbagai indikator fisiologis. Dataset ini kemungkinan mencakup ukuran atau penilaian terkuantifikasi dari stres yang dialami individu, yang mungkin dinilai melalui pelaporan diri atau cara lain.

# %% [markdown]
# - Dataset ini digunakan untuk melakukan Prediksi Tingkat Stress Seseorang Dengan Menggunakan Metode Classification Decision Tree
#
# - Mengidentifikasi variable predictor dan variable response
#     - X (variable bebas/predictor) = Humidity (Kelembapan (%RH)), Temperature (Suhu (F/Fahrenheit)), dan Step_count (Jumlah Langkah per hari).
#     - Y (variable tak bebas/response) = Stress_Level (Tingkat Stress).

# %% [markdown]
# # Data Preparation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Humidity      2001 non-null   float64
#  1   Temperature   2001 non-null   float64
#  2   Step_count    2001 non-null   int64
#  3   Stress_Level  2001 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 62.7 KB

# %%
df.isna().sum()
# Out:
# Humidity        0
# Temperature     0
# Step_count      0
# Stress_Level    0
# dtype: int64

# %%
df['Stress_Level'].value_counts()
# Out:
# 1    790
# 2    710
# 0    501
# Name: Stress_Level, dtype: int64

# %% [markdown]
# # Modelling Data
# Model yang digunakan untuk menganalisis data yaitu Classification Decision Tree

# %% [markdown]
# ### Melakukan Seleksi Fitur

# %%
selected_columns = ['Humidity', 'Temperature', 'Step_count']

# Split the data into training and testing sets
x = df[selected_columns]  # Select the columns for features
y = df['Stress_Level']  # Select the target column

# %% [markdown]
# ### Split Data Training dan Data Testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %% [markdown]
# ### Membuat Model Classification Decision Tree

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

dtc = DecisionTreeClassifier(
    ccp_alpha=0.0, class_weight=None, criterion='entropy',
    max_depth=4, max_features=None, max_leaf_nodes=None,
    min_impurity_decrease=0.0, min_samples_leaf=1,
    min_samples_split=2, min_weight_fraction_leaf=0.0,
    random_state=42, splitter='best'
)

model = dtc.fit(x_train, y_train)
dtc_acc = accuracy_score(y_test, dtc.predict(x_test))

print(f"akurasi data training = {accuracy_score(y_train, dtc.predict(x_train))}")
print(f"akurasi data testing = {dtc_acc} \n")

confusion = confusion_matrix(y_test, dtc.predict(x_test))
print(f"confusion matrix:\n{confusion}\n")
print(f"classification report:\n{classification_report(y_test, dtc.predict(x_test))}")

# Unpacking confusion matrix for a multi-class classification problem
tn, fp, fn = confusion.sum(axis=1) - np.diag(confusion)
tp = np.diag(confusion)

print("Confusion matrix:")
print(f"True Negative (TN): {tn}")
print(f"False Positive (FP): {fp}")
print(f"False Negative (FN): {fn}")
print(f"True Positive (TP): {tp}")
# Out:
# akurasi data training = 1.0
# akurasi data testing = 1.0
#
# confusion matrix:
# [[ 89   0   0]
#  [  0 175   0]
#  [  0   0 137]]
#
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        89
#            1       1.00      1.00      1.00       175
#            2       1.00      1.00      1.00       137
#
#     accuracy                           1.00       401
#    macro avg       1.00      1.00      1.00       401
# weighted avg       1.00      1.00      1.00       401
#
# Confusion matrix:
# True Negative (TN): 0
# False Positive (FP): 0
# False Negative (FN): 0
# True Positive (TP): [ 89 175 137]

# %% [markdown]
# akurasi data training = 1.0, akurasi data testing = 1.0, artinya, model yang telah dilatih menggunakan data training memiliki akurasi sebesar 100% atau 1.0. Ini berarti model mampu memprediksi dengan sempurna label atau target yang ada pada data training. Selain itu, saat model diuji dengan menggunakan data testing yang belum pernah dilihat sebelumnya, model juga mencapai akurasi sebesar 100% atau 1.0. Hal ini menunjukkan bahwa model memiliki kemampuan yang baik dalam mempelajari pola dari data training dan dapat menggeneralisasi dengan baik pada data yang belum pernah dilihat sebelumnya.

# %% [markdown]
# # Evaluation Data

# %% [markdown]
# ### Simulasi Model

# %%
input_data = (19.66, 93.55, 132)

input_data_as_numpy_array = np.array(input_data)

input_data_reshape = input_data_as_numpy_array.reshape(1, -1)

prediction = model.predict(input_data_reshape)
print(prediction)

if (prediction[0]==0):
    print ('Pasien Mengalami Stress Rendah')
elif prediction[0]==1:
    print ('Pasien Mengalami Stress Sedang')
else:
    print('Pasien Mengalami Stress Tinggi')
# Out:
# [2]
# Pasien Mengalami Stress Tinggi
# C:\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Visualisasi Pohon Keputusan

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model,
                   feature_names=selected_columns,
                   class_names=['Rendah','Sedang', 'Tinggi'],
                   filled=True
                   )

# %% [markdown]
# # Deployment

# %% [markdown]
# ### Save Model

# %%
import pickle

filename = 'PrediksiTingkatStress.sav'
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# # Link Untuk Aplikasi Prediksi Tingkat Stress Seseorang Dengan Menggunakan Metode Classification Decision Tree Dengan Menggunakan Streamlit Share

# %% [markdown]
# abcdd
